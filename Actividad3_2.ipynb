# %% [markdown]
# <a href="https://colab.research.google.com/github/Angel353/Valores_Nulos/blob/main/Actividad3_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Cargar archivo csv
from google.colab import files
files.upload()

# %%
#Carga desde un archivo .xlsx sin indice
df1 = pd.read_excel('Datos de Facturación.xlsx')
df1
# Out:
#       CVE_DOC    CVE_CLPV STATUS  CVE_VEND               FECHAELAB  FECHA_DOC  \
# 0      F29414        2465      C       1.0 2019-09-03 08:58:42.000 2019-09-03
# 1      F29415        3926      C       1.0 2019-09-03 09:55:14.000 2019-09-03
# 2      F29416        3926      C       1.0 2019-09-03 13:25:33.000 2019-09-03
# 3      F29417        3926      C       1.0 2019-09-03 13:33:23.000 2019-09-03
# 4      F29418        6813      C       2.0 2019-09-03 14:23:45.000 2019-09-03
# ...       ...         ...    ...       ...                     ...        ...
# 10890  F40306        8842      E       2.0 2023-03-06 16:09:39.013 2023-03-06
# 10891  F40307        6218    NaN       2.0 2023-03-06 16:38:42.933 2023-03-06
# 10892     NaN        5926      E       2.0 2023-03-06 17:02:33.390 2023-03-06
# 10893  F40309         361      E       2.0 2023-03-07 12:43:49.567 2023-03-07
# 10894  F40310        3011      E       2.0 2023-03-07 12:45:58.407 2023-03-07
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10895 entries, 0 to 10894
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CVE_DOC        10890 non-null  object
#  1   CVE_CLPV       10895 non-null  object
#  2   STATUS         10886 non-null  object
#  3   CVE_VEND       10847 non-null  float64
#  4   FECHAELAB      10893 non-null  datetime64[ns]
#  5   FECHA_DOC      10894 non-null  datetime64[ns]
#  6   FECHA_ENT      10893 non-null  object
#  7   FECHA_VEN      10895 non-null  datetime64[ns]
#  8   FECHA_CANCELA  358 non-null    datetime64[ns]
#  9   CAN_TOT        10889 non-null  float64
#  10  DES_TOT        10894 non-null  float64
#  11  DES_FIN        10892 non-null  float64
# dtypes: datetime64[ns](4), float64(4), object(4)
# memory usage: 1021.5+ KB

# %%
#Identificar valores nulos por columna
valores_nulos=df1.isnull().sum()
valores_nulos
# Out:
# CVE_DOC              5
# CVE_CLPV             0
# STATUS               9
# CVE_VEND            48
# FECHAELAB            2
# FECHA_DOC            1
# FECHA_ENT            2
# FECHA_VEN            0
# FECHA_CANCELA    10537
# CAN_TOT              6
# DES_TOT              1
# DES_FIN              3
# dtype: int64

# %%
#Hacer copia
df11 = df1.copy()

# %%
# Dropear columna (Fecha_Cancela)
df11 = df1.drop(['FECHA_CANCELA'], axis = 1)
df11

# Se elimina la columna porque la gran mayoría de los datos son nulos desvirtuando analisis
# Out:
#       CVE_DOC    CVE_CLPV STATUS  CVE_VEND               FECHAELAB  FECHA_DOC  \
# 0      F29414        2465      C       1.0 2019-09-03 08:58:42.000 2019-09-03
# 1      F29415        3926      C       1.0 2019-09-03 09:55:14.000 2019-09-03
# 2      F29416        3926      C       1.0 2019-09-03 13:25:33.000 2019-09-03
# 3      F29417        3926      C       1.0 2019-09-03 13:33:23.000 2019-09-03
# 4      F29418        6813      C       2.0 2019-09-03 14:23:45.000 2019-09-03
# ...       ...         ...    ...       ...                     ...        ...
# 10890  F40306        8842      E       2.0 2023-03-06 16:09:39.013 2023-03-06
# 10891  F40307        6218    NaN       2.0 2023-03-06 16:38:42.933 2023-03-06
# 10892     NaN        5926      E       2.0 2023-03-06 17:02:33.390 2023-03-06
# 10893  F40309         361      E       2.0 2023-03-07 12:43:49.567 2023-03-07
# 10894  F40310        3011      E       2.0 2023-03-07 12:45:58.407 2023-03-07
#
# ...

# %%
#Sustituir valores nulos con "forward fill"
df11["FECHAELAB"] =df1["FECHAELAB"].fillna(method="ffill")
df11["FECHA_DOC"] =df1["FECHA_DOC"].fillna(method="ffill")
df11["FECHA_ENT"] =df1["FECHA_ENT"].fillna(method="ffill")
df11["CVE_VEND"] =df1["CVE_VEND"].fillna(method="ffill")
df11["STATUS"] =df1["STATUS"].fillna(method="ffill")

# Se sustituye por los valores siguientes de las filas ya que se sigue un patrón consecuente en las columnas

# %%
# Sustituir por registro único de identificación

df11["CVE_DOC"] =df1["CVE_DOC"].fillna("F00000")

# Se sustituyen los nulos de registro siendo intercambiados por una clave de identificación única

# %%
#Identificar valores nulos por columna
valores_nulos=df11.isnull().sum()
valores_nulos
# Out:
# CVE_DOC      0
# CVE_CLPV     0
# STATUS       0
# CVE_VEND     0
# FECHAELAB    0
# FECHA_DOC    0
# FECHA_ENT    0
# FECHA_VEN    0
# CAN_TOT      6
# DES_TOT      1
# DES_FIN      3
# dtype: int64

# %%
# Sustituir por mediana

df11["DES_TOT"]= df11["DES_TOT"].fillna(round(df1["DES_TOT"].median(),1))

df11["DES_FIN"]= df11["DES_FIN"].fillna(round(df1["DES_FIN"].median(),1))
df11

# Se sustituye por la mediana ya que la gran mayoría de valores comparten número siendo en este caso el "0"
# Out:
#       CVE_DOC    CVE_CLPV STATUS  CVE_VEND               FECHAELAB  FECHA_DOC  \
# 0      F29414        2465      C       1.0 2019-09-03 08:58:42.000 2019-09-03
# 1      F29415        3926      C       1.0 2019-09-03 09:55:14.000 2019-09-03
# 2      F29416        3926      C       1.0 2019-09-03 13:25:33.000 2019-09-03
# 3      F29417        3926      C       1.0 2019-09-03 13:33:23.000 2019-09-03
# 4      F29418        6813      C       2.0 2019-09-03 14:23:45.000 2019-09-03
# ...       ...         ...    ...       ...                     ...        ...
# 10890  F40306        8842      E       2.0 2023-03-06 16:09:39.013 2023-03-06
# 10891  F40307        6218      E       2.0 2023-03-06 16:38:42.933 2023-03-06
# 10892  F00000        5926      E       2.0 2023-03-06 17:02:33.390 2023-03-06
# 10893  F40309         361      E       2.0 2023-03-07 12:43:49.567 2023-03-07
# 10894  F40310        3011      E       2.0 2023-03-07 12:45:58.407 2023-03-07
#
# ...

# %%
# Sustituir por promedio

df11["CAN_TOT"]= df11["CAN_TOT"].fillna(round(df1["CAN_TOT"].mean(),1))
df11

# La cantidad en pago se rellena con el promedio de las facturas para no desvirtuar próximos análisis
# Out:
#       CVE_DOC    CVE_CLPV STATUS  CVE_VEND               FECHAELAB  FECHA_DOC  \
# 0      F29414        2465      C       1.0 2019-09-03 08:58:42.000 2019-09-03
# 1      F29415        3926      C       1.0 2019-09-03 09:55:14.000 2019-09-03
# 2      F29416        3926      C       1.0 2019-09-03 13:25:33.000 2019-09-03
# 3      F29417        3926      C       1.0 2019-09-03 13:33:23.000 2019-09-03
# 4      F29418        6813      C       2.0 2019-09-03 14:23:45.000 2019-09-03
# ...       ...         ...    ...       ...                     ...        ...
# 10890  F40306        8842      E       2.0 2023-03-06 16:09:39.013 2023-03-06
# 10891  F40307        6218      E       2.0 2023-03-06 16:38:42.933 2023-03-06
# 10892  F00000        5926      E       2.0 2023-03-06 17:02:33.390 2023-03-06
# 10893  F40309         361      E       2.0 2023-03-07 12:43:49.567 2023-03-07
# 10894  F40310        3011      E       2.0 2023-03-07 12:45:58.407 2023-03-07
#
# ...

# %%
#Identificar valores nulos por columna
valores_nulos=df11.isnull().sum()
valores_nulos
# Out:
# CVE_DOC      0
# CVE_CLPV     0
# STATUS       0
# CVE_VEND     0
# FECHAELAB    0
# FECHA_DOC    0
# FECHA_ENT    0
# FECHA_VEN    0
# CAN_TOT      0
# DES_TOT      0
# DES_FIN      0
# dtype: int64

# %%
#Cargar archivo csv
from google.colab import files
files.upload()

# %%
df2 = pd.read_excel('Detalle precios y productos fabricados 2022.xlsx')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1426 entries, 0 to 1425
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CVE_DOC                    1423 non-null   object
#  1   FECHA_DOC                  1423 non-null   datetime64[ns]
#  2   NOMBRE_VENDEDOR            1424 non-null   object
#  3   NOMBRE_CLIENTE             1424 non-null   object
#  4   CANT                       1419 non-null   float64
#  5   CVE_ART                    1424 non-null   object
#  6   DESCR                      1424 non-null   object
#  7   PRECIO_UNITARIO            1424 non-null   float64
#  8   COSTO_UNITARIO             1422 non-null   float64
#  9   COSTO_UNITARIO_CALCULADO   1424 non-null   float64
#  10  SUBTOTAL_PARTIDA           1422 non-null   float64
#  11  COSTO_TOTAL_CALCULADO      1426 non-null   float64
#  12  MARGEN_UNITARIO_CALCULADO  1426 non-null   float64
# ...

# %%
#Identificar valores nulos por columna
valores_nulos=df2.isnull().sum()
valores_nulos
# Out:
# CVE_DOC                      3
# FECHA_DOC                    3
# NOMBRE_VENDEDOR              2
# NOMBRE_CLIENTE               2
# CANT                         7
# CVE_ART                      2
# DESCR                        2
# PRECIO_UNITARIO              2
# COSTO_UNITARIO               4
# COSTO_UNITARIO_CALCULADO     2
# SUBTOTAL_PARTIDA             4
# COSTO_TOTAL_CALCULADO        0
# MARGEN_UNITARIO_CALCULADO    0
# MARGEN_TOTAL_CALCULADO       0
# dtype: int64

# %%
#Hacer copia
df22 = df2.copy()

# %%
# Sustituir por registro único de identificación

df22["CVE_DOC"] =df2["CVE_DOC"].fillna("F00000")
df22["NOMBRE_VENDEDOR"] =df2["NOMBRE_VENDEDOR"].fillna("Vendedor No Identificado")
df22["NOMBRE_CLIENTE"] =df2["NOMBRE_CLIENTE"].fillna("Cliente No Identificado")
df22["CVE_ART"] =df2["CVE_ART"].fillna("Cliente No Identificado")
df22["DESCR"] =df2["DESCR"].fillna("Producto No Identificado")

# Se sustituyen los nulos de registro siendo intercambiados por una clave de identificación única

# %%
#Identificar valores nulos por columna
valores_nulos=df22.isnull().sum()
valores_nulos
# Out:
# CVE_DOC                      0
# FECHA_DOC                    3
# NOMBRE_VENDEDOR              0
# NOMBRE_CLIENTE               0
# CANT                         7
# CVE_ART                      0
# DESCR                        0
# PRECIO_UNITARIO              2
# COSTO_UNITARIO               4
# COSTO_UNITARIO_CALCULADO     2
# SUBTOTAL_PARTIDA             4
# COSTO_TOTAL_CALCULADO        0
# MARGEN_UNITARIO_CALCULADO    0
# MARGEN_TOTAL_CALCULADO       0
# dtype: int64

# %%
#Sustituir valores nulos con "forward fill"
df22["FECHA_DOC"] =df2["FECHA_DOC"].fillna(method="ffill")

# Se sustituye por los valores siguientes de las filas ya que se sigue un patrón consecuente en las columnas

# %%
#Identificar valores nulos por columna
valores_nulos=df22.isnull().sum()
valores_nulos
# Out:
# CVE_DOC                      0
# FECHA_DOC                    0
# NOMBRE_VENDEDOR              0
# NOMBRE_CLIENTE               0
# CANT                         7
# CVE_ART                      0
# DESCR                        0
# PRECIO_UNITARIO              2
# COSTO_UNITARIO               4
# COSTO_UNITARIO_CALCULADO     2
# SUBTOTAL_PARTIDA             4
# COSTO_TOTAL_CALCULADO        0
# MARGEN_UNITARIO_CALCULADO    0
# MARGEN_TOTAL_CALCULADO       0
# dtype: int64

# %%
# Sustituir por mediana

df22["CANT"]= df22["CANT"].fillna(round(df2["CANT"].median(),1))
df22["PRECIO_UNITARIO"]= df22["PRECIO_UNITARIO"].fillna(round(df2["PRECIO_UNITARIO"].median(),1))
df22["COSTO_UNITARIO"]= df22["COSTO_UNITARIO"].fillna(round(df2["COSTO_UNITARIO"].median(),1))
df22["COSTO_UNITARIO_CALCULADO"]= df22["COSTO_UNITARIO_CALCULADO"].fillna(round(df2["COSTO_UNITARIO_CALCULADO"].median(),1))
df22["SUBTOTAL_PARTIDA"]= df22["SUBTOTAL_PARTIDA"].fillna(round(df2["COSTO_UNITARIO"].median(),1))

df22

# Se sustituye por la mediana ya que la gran mayoría de valores comparten número siendo en este caso el "0"
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0     F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2     F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 3     F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...      ...        ...                        ...
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA
#
#                     NOMBRE_CLIENTE  CANT       CVE_ART  \
# 0               PÚBLICO EN GENERAL   1.0      TUE00244
# 1     JUAN ANTONIO RESENDIZ UGALDE   1.0      TUA00028
# 2        ANA BARBARA CRUZ PALACIOS   7.0        TP0007
# 3             OMAR RODRIGUEZ GOMEZ   1.0        TP0001
# 4               PÚBLICO EN GENERAL   2.0       BP00242
# ...

# %%
#Identificar valores nulos por columna
valores_nulos=df22.isnull().sum()
valores_nulos
# Out:
# CVE_DOC                      0
# FECHA_DOC                    0
# NOMBRE_VENDEDOR              0
# NOMBRE_CLIENTE               0
# CANT                         0
# CVE_ART                      0
# DESCR                        0
# PRECIO_UNITARIO              0
# COSTO_UNITARIO               0
# COSTO_UNITARIO_CALCULADO     0
# SUBTOTAL_PARTIDA             0
# COSTO_TOTAL_CALCULADO        0
# MARGEN_UNITARIO_CALCULADO    0
# MARGEN_TOTAL_CALCULADO       0
# dtype: int64

# %%
# Database en CSV
df11.to_csv("df1.csv")

# Descargar archivo filtrado en CSV
from google.colab import files
files.download("df1.csv")

# %%
# Database en CSV
df22.to_csv("df2.csv")

# Descargar archivo filtrado en CSV
from google.colab import files
files.download("df2.csv")
